# %% [markdown]
# Imports

# %%
import requests
import pandas as pd
import Keystuff
import json
import time

# %% [markdown]
# Main

# %%
log_df = pd.read_csv(r"~/CoinStuff/coin_cap_data.csv")


url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    
parameters = {
        'start': '1',
        'limit': '25',
        'convert': 'USD'
    }
    
header_stuff = {
        'Accepts': 'application/json',
        'X-CMC_PRO_API_KEY': Keystuff.APIKey,
    }
    
resp = requests.get(url, params=parameters, headers=header_stuff)
   
json_data = json.loads(resp.text)
    
coin_df = pd.json_normalize(json_data['data'])
    
final_df = log_df.append(coin_df, ignore_index=True)
    
final_df.to_csv(r'~/Projects/coin_cap_data.csv')

print("Successful Run")
# Out:
# Successful Run

# %%
.csv Analysis

# %%
log_df = pd.read_csv(r"~/Projects/coin_market_cap_data.csv")

log_df.head()
# Out:
#    Unnamed: 0    id          name symbol          slug  num_market_pairs  \
# 0           0     1       Bitcoin    BTC       bitcoin              8167
# 1           1  1027      Ethereum    ETH      ethereum              4549
# 2           2  1839  Binance Coin    BNB  binance-coin               539
# 3           3   825        Tether   USDT        tether             19922
# 4           4  5426        Solana    SOL        solana               193
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...   21000000.0
# 1  ['mineable', 'pow', 'smart-contracts', 'ethere...          NaN
# 2  ['marketplace', 'centralized-exchange', 'payme...  166801148.0
# 3  ['payments', 'stablecoin', 'asset-backed-stabl...          NaN
# ...
